# %%
import pandas as pd
import openpyxl
from datetime import date

num = 1
row = 0
col = 2
cnt = 0
df = pd.read_excel("resolved.xlsx")

wb = openpyxl.Workbook()
wb.active.title = "data"
wb1 = wb["data"]

print(df.values[row][col])
in_str = ""
be = df.values[0][0]
while(cnt < 30):
    if be == df.values[cnt][0]:
        print(df.values[cnt][0])
        in_str += (str(int(df.values[cnt][1])) + df.values[cnt][2])
        print(in_str)
    elif be < df.values[cnt][0]:
        be = df.values[cnt][0]
        in_str = ""
    cnt += 1           
# wb1['A'+str(1)] = "hi111"


wb.save('/home/misys/github/artificial_Intelligence_ssu/Project4/new_data.xlsx')
# Out:
# 안심은 불고기 양념하여 30분간 재워 국물 없이 구워 한 김 식으면 한입 크기로 자른다.
# 1.0
# 2안심은 불고기 양념하여 30분간 재워 국물 없이 구워 한 김 식으면 한입 크기로 자른다.
# 1.0
# 2안심은 불고기 양념하여 30분간 재워 국물 없이 구워 한 김 식으면 한입 크기로 자른다.3청포묵은 고기와 비슷한 크기로 잘라 끓는 물에 데쳐내고 계란은 노른자와 흰자를 분리해 지단부쳐 곱게 채썬다.
# 1.0
# 2안심은 불고기 양념하여 30분간 재워 국물 없이 구워 한 김 식으면 한입 크기로 자른다.3청포묵은 고기와 비슷한 크기로 잘라 끓는 물에 데쳐내고 계란은 노른자와 흰자를 분리해 지단부쳐 곱게 채썬다.4콩나물과 숙주, 미나리는 데쳐서 국간장과 참기름으로 간하고, 고사리와 도라지는 참기름을 두른 프라이팬에 살짝 볶아놓는다.
# 1.0
# 2안심은 불고기 양념하여 30분간 재워 국물 없이 구워 한 김 식으면 한입 크기로 자른다.3청포묵은 고기와 비슷한 크기로 잘라 끓는 물에 데쳐내고 계란은 노른자와 흰자를 분리해 지단부쳐 곱게 채썬다.4콩나물과 숙주, 미나리는 데쳐서 국간장과 참기름으로 간하고, 고사리와 도라지는 참기름을 두른 프라이팬에 살짝 볶아놓는다.5밥을 참기름으로 무쳐 그릇에 담고 준비한 재료를 고루 얹는다.
# 2.0
# 2차수수는 붉은 물이 안 나올 때까지 깨끗이 씻어 놓는다.
# 2.0
# 2차수수는 붉은 물이 안 나올 때까지 깨끗이 씻어 놓는다.3콩은 불려서 일어 건져놓고, 팥은 삶아서 건져놓고 삶은 물은 받아 놓는다.
# 2.0
# 2차수수는 붉은 물이 안 나올 때까지 깨끗이 씻어 놓는다.3콩은 불려서 일어 건져놓고, 팥은 삶아서 건져놓고 삶은 물은 받아 놓는다.4차조는 씻어서 잘 일은 후 건져놓는다.
# 2.0
# ...
